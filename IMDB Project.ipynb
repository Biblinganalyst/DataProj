# %%
import pandas as pd

# %%
movies=pd.read_csv('http://bit.ly/imdbratings')

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
#movies.drop(['content_rating', 'actors_list'], axis=1, inplace=True )
movies.drop([0,1], axis=0, inplace=True )

# %%
movies.head()
# Out:
#    star_rating                           title    genre  duration
# 2          9.1          The Godfather: Part II    Crime       200
# 3          9.0                 The Dark Knight   Action       152
# 4          8.9                    Pulp Fiction    Crime       154
# 5          8.9                    12 Angry Men    Drama        96
# 6          8.9  The Good, the Bad and the Ugly  Western       161

# %%
#movies.genre
movies[['genre','duration']]
# Out:
#          genre  duration
# 0        Crime       142
# 1        Crime       175
# 2        Crime       200
# 3       Action       152
# 4        Crime       154
# ..         ...       ...
# 974     Comedy       116
# 975  Adventure       118
# 976     Action       138
# 977     Horror       114
# 978      Crime       126
#
# [979 rows x 2 columns]

# %%
movies.sort_values('duration', ascending=False)
# Out:
#      star_rating                              title      genre  duration
# 476          7.8                             Hamlet      Drama       242
# 157          8.2                 Gone with the Wind      Drama       238
# 78           8.4        Once Upon a Time in America      Crime       229
# 142          8.3  Lagaan: Once Upon a Time in India  Adventure       224
# 445          7.9               The Ten Commandments  Adventure       220
# ..           ...                                ...        ...       ...
# 88           8.4                            The Kid     Comedy        68
# 293          8.1                          Duck Soup     Comedy        68
# 258          8.1        The Cabinet of Dr. Caligari      Crime        67
# 338          8.0                Battleship Potemkin    History        66
# 389          8.0                             Freaks      Drama        64
#
# [977 rows x 4 columns]

# %%
movies.describe(include=object)
# Out:
#           title  genre
# count       977    977
# unique      973     16
# top     Dracula  Drama
# freq          2    278

# %%
movies[movies.star_rating >=8.4]
# Out:
#     star_rating                           title      genre  duration
# 2           9.1          The Godfather: Part II      Crime       200
# 3           9.0                 The Dark Knight     Action       152
# 4           8.9                    Pulp Fiction      Crime       154
# 5           8.9                    12 Angry Men      Drama        96
# 6           8.9  The Good, the Bad and the Ugly    Western       161
# ..          ...                             ...        ...       ...
# 95          8.4                   All About Eve      Drama       138
# 96          8.4                         Yojimbo     Action       110
# 97          8.4                       The Sting     Comedy       129
# 98          8.4                        Rashomon      Crime        88
# 99          8.4                         Amadeus  Biography       160
#
# [98 rows x 4 columns]

# %%
movies[(movies.star_rating >= 8.4) & (movies.genre == 'Action')]
# Out:
#     star_rating                                           title   genre  \
# 3           9.0                                 The Dark Knight  Action
# 11          8.8                                       Inception  Action
# 12          8.8  Star Wars: Episode V - The Empire Strikes Back  Action
# 19          8.7                                       Star Wars  Action
# 20          8.7                                      The Matrix  Action
# 36          8.6                             Saving Private Ryan  Action
# 37          8.6                         Raiders of the Lost Ark  Action
# 43          8.5                           The Dark Knight Rises  Action
# 44          8.5                                       Gladiator  Action
# 45          8.5                      Terminator 2: Judgment Day  Action
# 75          8.4                                          Aliens  Action
# 80          8.4      Star Wars: Episode VI - Return of the Jedi  Action
# ...

# %%
(movies.star_rating >= 8.4) & (movies.genre == 'Action')
# Out:
# 2      False
# 3       True
# 4      False
# 5      False
# 6      False
#        ...
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# Length: 977, dtype: bool
